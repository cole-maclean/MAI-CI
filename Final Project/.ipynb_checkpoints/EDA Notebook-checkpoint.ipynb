# %% [markdown]
# <b>Scratch Pad</b>
# User interaction data (ie # of comments, per subreddit etc)  - Can be used as word move weight/count
# Architecture - WMD fed into net with features as top X closest users (ie user 1,8,56,123) which are ordered by their inherent embedding distances from a reference user (ie a default sub user), could also include furthest users, add NLP/content features for fine tuning suggestions from close users.
# Need to deal with aging problem of recommender systems
# Need to update network gefx file
# identify users very far from you to introduce outside perspectives
# Center of gravity of user comments over time of user account age

# %%
import json
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ggplot import *
import networkx as nx
from networkx.readwrite import json_graph
from operator import itemgetter
from collections import Counter
from bs4 import BeautifulSoup
from pyemd import emd
from sklearn.metrics import euclidean_distances
# %matplotlib inline
os.chdir("C:/Users/macle/Desktop/UPC Masters/Semester 2/CI/Final Project")

# %%
with open('reddit_data.json','r') as data_file:    
    reddit_data = json.load(data_file)

# %%
df = pd.DataFrame(reddit_data,columns=['user','subreddit','submission','utc_stamp','rnd_words'])
df['utc_stamp'] = pd.to_datetime(df['utc_stamp'],unit='s')
df.head()
# Out:
#            user             subreddit  \
# 0  popesnutsack         worldpolitics
# 1  popesnutsack  Offensive_Wallpapers
# 2  popesnutsack                 funny
# 3  popesnutsack  ImGoingToHellForThis
# 4  popesnutsack     mildlyinteresting
#
#                                           submission           utc_stamp  \
# 0  [102 million dead California trees 'unpreceden... 2016-11-20 14:20:35
# 1     [Ya gotta love PornHub comments [2400 x 1350]] 2016-11-20 14:16:12
# 2                             ["Oh my fucking god!"] 2016-11-20 13:48:03
# 3                              [First Day in Office] 2016-11-19 01:09:57
# 4  [We do Not hire LIBERALS. Rude sign in conveni... 2016-11-18 23:48:46
#
#                          rnd_words
# 0           [water, If, one, tree]
# 1     [My, next, alimoni, payment]
# 2                  [Now, hard, on]
# 3       [Can, hope, cheeto, board]
# 4  [Veri, eloqu, craft, wordsmith]

# %% [markdown]
# <h2>Dataset Size</h2>

# %%
print("Unique Users = " + str(len(df.groupby('user')['user'].nunique())))
print("Unique Subreddits = " + str(len(df.groupby('subreddit')['subreddit'].nunique())))
print("Unique Submissions = " + str(len(df.groupby(['user','subreddit'])['submission'].nunique())))
df.shape
# Out:
# Unique Users = 1220
# Unique Subreddits = 9869
# Unique Submissions = 72247
# (753625, 5)

# %% [markdown]
# <h2>Subreddit Data</h2>

# %%
user_subs = df.groupby(['user'])['subreddit'].nunique()
plt.hist(user_subs.values, bins=100)
plt.title("User vs Sub Counts Histogram")
plt.show()

# %%
sub_users = df.groupby(['subreddit'])['user'].nunique()
data_tuple = pd.DataFrame([(sub,count) for sub,count in sub_users.items()],columns=["sub","user_count"])
sorted_df = data_tuple.sort_values(by='user_count',ascending=False)
sorted_df.head(50)
# Out:
#                        sub  user_count
# 411              AskReddit         943
# 8258                  pics         763
# 6703                 funny         748
# 9349         todayilearned         695
# 9591                videos         651
# 6821                  gifs         650
# 6753                gaming         632
# 9772             worldnews         599
# 7951                  news         563
# 4092        Showerthoughts         541
# 5423                   aww         529
# 7759     mildlyinteresting         525
# 7838                movies         524
# 4916                   WTF         487
# 2215                  IAmA         471
# 8328              politics         436
# 158          AdviceAnimals         428
# 9215            television         382
# 8709               science         381
# 6470     explainlikeimfive         376
# 8021           nottheonion         371
# 2665           LifeProTips         358
# 3033                 Music         354
# 9197            technology         338
# 2464                 Jokes         330
# 3287         OldSchoolCool         315
# 4559            The_Donald         310
# 9317                  tifu         300
# 7237     interestingasfuck         294
# 8969                 space         286
# 8208          pcmasterrace         278
# 6076                creepy         277
# 6173       dataisbeautiful         273
# 8993                sports         272
# 1804            Futurology         268
# 647     BlackPeopleTwitter         265
# 6610                  food         264
# 5680                 books         248
# 8252      photoshopbattles         240
# 4814         UpliftingNews         234
# 1180                   DIY         228
# 5380               atheism         224
# 9759              woahdude         222
# 2268  ImGoingToHellForThis         206
# 8505          reactiongifs         204
# 1465             EarthPorn         203
# 1374         Documentaries         202
# 4728        TumblrInAction         201
# 8306             pokemongo         200
# 1891          GetMotivated         197

# %% [markdown]
# <h2>User Temporal Data</h2>

# %%
pd.groupby(df,by=[df['user'],df['subreddit'],df['utc_stamp'].dt.month,df['utc_stamp'].dt.year]).head()
# Out:
#                 user             subreddit  \
# 0       popesnutsack         worldpolitics
# 1       popesnutsack  Offensive_Wallpapers
# 2       popesnutsack                 funny
# 3       popesnutsack  ImGoingToHellForThis
# 4       popesnutsack     mildlyinteresting
# 5       popesnutsack             AskReddit
# 6       popesnutsack         worldpolitics
# 7       popesnutsack             AskReddit
# 8       popesnutsack             AskReddit
# 9       popesnutsack                   WTF
# 10      popesnutsack               offbeat
# 11      popesnutsack               atheism
# 12      popesnutsack         worldpolitics
# 13      popesnutsack         worldpolitics
# 14      popesnutsack                   WTF
# 15      popesnutsack               offbeat
# 16      popesnutsack                creepy
# 17      popesnutsack                  pics
# 18      popesnutsack                  pics
# 19      popesnutsack              politics
# 20      popesnutsack                   WTF
# 21      popesnutsack             worldnews
# 22      popesnutsack             worldnews
# 23      popesnutsack             AskReddit
# 24      popesnutsack              facepalm
# 25      popesnutsack               science
# 26      popesnutsack             worldnews
# 27      popesnutsack         todayilearned
# 28      popesnutsack                 funny
# 29      popesnutsack               atheism
# ...              ...                   ...
# 753583      pezpants          reactiongifs
# 753584      pezpants                 funny
# 753585      pezpants          progresspics
# 753586      pezpants                hockey
# 753587      pezpants                   aww
# 753588      pezpants                 funny
# 753589      pezpants                 funny
# 753590      pezpants             Chihuahua
# 753591      pezpants                 funny
# 753592      pezpants             AskReddit
# 753593      pezpants                   ufc
# 753594      pezpants                   ufc
# 753595      pezpants                 funny
# 753596      pezpants                   ufc
# 753597      pezpants                   ufc
# 14        [place, russia, like, swear, live, three, hors]
# 15                                  [So, take, bath, not]
# 16              [That, motherinlaw, Fix, titl, pleas, OP]
# 17              [crosssing, bright, He, die, side, Alway]
# 18                           [Id, let, eat, cracker, bed]
# 19      [Dear, taxpay, go, fuck, yourself, Sincer, rep...
# 20                       [Get, cart, Your, fool, anybodi]
# 21                  [And, subcontractor, Like, make, all]
# 22                       [equival, david, So, star, wear]
# 23                            [High, veloc, lead, poison]
# 24                               [Mr, Darwin, couldpleas]
# 25            [stop, scream, Now, fire, kept, fire, wear]
# 26                        [Im, ISI, best, camera, it, 60]
# 27                                          [Your, towel]
# 28                    [It, 16hr, now, cost, live, adjust]
# 29                       [cow, worshipp, love, WTF, good]
# ...                                                   ...
# 753583         [never, requir, I, shift, it, phone, work]
# 753584                               [Spongebob, pezpant]
# 753585                               [Put, weight, littl]
# 753586                         [use, Achil, take, longer]
# 753587                       [littl, look, younger, ladi]
# 753588                                           [Im, 30]
# 753589                       [dont, kind, I, Im, dirtbag]
# 753590                          [doga, name, Alleb, Your]
# 753591                                        [one, Yeah]
# 753592                                    [poopouri, Buy]
# 753593                            [Thi, UFC, noth, fight]
# 753594                                    [noth, UFC, It]
# 753595                                           [US, We]
# 753596                                          [Or, UFC]
# 753597                                     [But, UFC, it]
# 753598                                   [Subscrib, rbox]
# 753599              [I, favorit, front, team, junior, up]
# 753600                   [best, hedgehog, hedgehog, Reno]
# 753601                                            [Sourc]
# 753602                    [care, now, advertis, Who, Are]
# 753608  [retard, doctor, that, ask, ok, handicap, mental]
# 753609                            [figur, troll, I, cant]
# 753610      [chocol, definit, FYE, music, I, think, haha]
# 753611                   [no, stupid, 90, time, Im, hope]
# 753612                          [Later, episod, live, 98]
# 753613                             [like, Reggi, I, Watt]
# 753614           [cloth, That, make, think, take, I, off]
# 753616                           [miss, late, sure, miss]
# 753617                    [How, I, gnat, amount, augsept]
# 753623                             [never, caught, , got]
#
# [385145 rows x 5 columns]

# %% [markdown]
# <h2>Network Data</h2>

# %%
def MakeList(x):
    T = tuple(x)
    if len(T) > 1:
        return T
    else:
        return T[0]
f = {'subreddit':['count'], 'utc_stamp':[np.min,np.max],'submission': MakeList,'rnd_words': MakeList}
grouped = df.groupby(['user','subreddit']).agg(f)

# %%
grouped.head()
# Out:
#                                                                    rnd_words  \
#                                                                     MakeList
# user   subreddit
# -DEAD- 1200isplenty                               [Im, pikelet, call, Where]
#        ANormalDayInRussia           ([look, Someth, me, fake], [Look, fake])
#        Bonsai              ([it, see, make, Ill, I], [AKL], [know, Next, ...
#        Catan               [therefor, consequ, move, transfer, therefor, ...
#        DailyInkblot                           [eye, mustach, Clearli, coupl]
#
#                               utc_stamp                \
#                                    amin          amax
# user   subreddit
# -DEAD- 1200isplenty        1.474837e+09  1.474837e+09
#        ANormalDayInRussia  1.455337e+09  1.456432e+09
#        Bonsai              1.478570e+09  1.478635e+09
#        Catan               1.473304e+09  1.473304e+09
#        DailyInkblot        1.467325e+09  1.467325e+09
#
#                                                                   submission  \
#                                                                     MakeList
# user   subreddit
# -DEAD- 1200isplenty        [275, calories, for, this, stack, of, pancakes...
#        ANormalDayInRussia  ([Just, a, normal, sunday, drive], [Hell, of, ...
#        Bonsai              ([New, Zealand, National, Bonsai, show], [New,...
#        Catan                                                [Rule, question]
#        DailyInkblot                                              [6/30/2016]
#
#                           subreddit
#                               count
# user   subreddit
# -DEAD- 1200isplenty               1
#        ANormalDayInRussia         2
#        Bonsai                     3
#        Catan                      1
#        DailyInkblot               1

# %%
users = df.groupby('user')['user'].all()[0:2]
subreddits = list(df.groupby('subreddit')['subreddit'].nunique().keys())
users
# Out:
# user
# -DEAD-            -DEAD-
# -Doomcrow-    -Doomcrow-
# Name: user, dtype: object

# %%
G = nx.Graph()
loop_count = 0
for usr in users:
    if loop_count % 5 == 0:
        print (str(round(loop_count/len(users)*100,2)) + " % complete")
    loop_count = loop_count + 1
    for i,i_sub in enumerate(grouped['subreddit']['count'][usr].keys()):
        for j,j_sub in enumerate(grouped['subreddit']['count'][usr].keys()):
            if j > i:
                edge_id = '-'.join(sorted([i_sub,j_sub]))
                if G.has_edge(i_sub,j_sub) == False:
                    G.add_edge(i_sub,j_sub,{'source':i_sub,'target':j_sub,'weight':1,'id':edge_id})
                else:
                    G[i_sub][j_sub]['weight'] = G[i_sub][j_sub]['weight'] + 1
write_gexf(G,'reddit_network.gexf')
# Out:
# 0.0 % complete

# %% [markdown]
# <h3>Network Embedding</h3>

# %%
soup = BeautifulSoup(open("full_network.html"),"html.parser")

# %%
graph_cords = {}
nodes = soup.findAll('node')
for nd in nodes:
    crds = nd.find('viz:position')
    graph_cords[nd['label']] = [crds['x'],crds['y']]

# %%
def pairwise_emd(user_A,user_B,graph_cords):
    set_subs = [sub for sub in set(list(user_A.keys())+list(user_A.keys())) if sub in graph_cords.keys()]
    sub_cords = np.array([graph_cords[sub] for sub in set_subs]) 
    A_interacts = np.array([user_A[sub] if sub in list(user_A.keys()) else 0 for sub in set_subs])
    B_interacts = np.array([user_B[sub] if sub in list(user_B.keys()) else 0 for sub in set_subs])
    euc_dists = euclidean_distances(sub_cords,sub_cords)
    emd_dist = emd(A_interacts.astype(np.double), B_interacts.astype(np.double), euc_dists.astype(np.double))
    return emd_dist

# %%
pairwise_emd(grouped['subreddit']['count']['-DEAD-'].sort_values(ascending=False),
             grouped['subreddit']['count']['-Doomcrow-'].sort_values(ascending=False),graph_cords)
# Out:
# ['newzealand', 'electronic_cigarette', 'skeptic', 'WeAreTheMusicMakers', 'serialpodcast']
# 0.0
