# %% [markdown]
# <b>Scratch Pad</b>
# User interaction data (ie # of comments, per subreddit etc)

# %%
import json
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ggplot import *
import networkx as nx
from networkx.readwrite import json_graph
from operator import itemgetter
from collections import Counter
from bs4 import BeautifulSoup
# %matplotlib inline
os.chdir("C:/Users/macle/Desktop/UPC Masters/Semester 2/CI/Final Project")

# %%
with open('reddit_data.json','r') as data_file:    
    reddit_data = json.load(data_file)

# %%
df = pd.DataFrame(reddit_data,columns=['user','subreddit','submission','utc_stamp','rnd_words'])
df.head()
# Out:
#            user             subreddit  \
# 0  popesnutsack         worldpolitics
# 1  popesnutsack  Offensive_Wallpapers
# 2  popesnutsack                 funny
# 3  popesnutsack  ImGoingToHellForThis
# 4  popesnutsack     mildlyinteresting
#
#                                           submission     utc_stamp  \
# 0  [102 million dead California trees 'unpreceden...  1.479652e+09
# 1     [Ya gotta love PornHub comments [2400 x 1350]]  1.479651e+09
# 2                             ["Oh my fucking god!"]  1.479650e+09
# 3                              [First Day in Office]  1.479518e+09
# 4  [We do Not hire LIBERALS. Rude sign in conveni...  1.479513e+09
#
#                          rnd_words
# 0           [water, If, one, tree]
# 1     [My, next, alimoni, payment]
# 2                  [Now, hard, on]
# 3       [Can, hope, cheeto, board]
# 4  [Veri, eloqu, craft, wordsmith]

# %% [markdown]
# <h2>Dataset Size</h2>

# %%
print("Unique Users = " + str(len(df.groupby('user')['user'].nunique())))
print("Unique Subreddits = " + str(len(df.groupby('subreddit')['subreddit'].nunique())))
print("Unique Submissions = " + str(len(df.groupby(['user','subreddit'])['submission'].nunique())))
df.shape
# Out:
# Unique Users = 1220
# Unique Subreddits = 9869
# Unique Submissions = 72247
# (753625, 5)

# %% [markdown]
# <h2>Subreddit Data</h2>

# %%
user_subs = df.groupby(['user'])['subreddit'].nunique()
plt.hist(user_subs.values, bins=100)
plt.title("User vs Sub Counts Histogram")
plt.show()

# %%
sub_users = df.groupby(['subreddit'])['user'].nunique()
data_tuple = pd.DataFrame([(sub,count) for sub,count in sub_users.items()],columns=["sub","user_count"])
sorted_df = data_tuple.sort_values(by='user_count',ascending=False)
sorted_df.head(50)
# Out:
#                        sub  user_count
# 411              AskReddit         943
# 8258                  pics         763
# 6703                 funny         748
# 9349         todayilearned         695
# 9591                videos         651
# 6821                  gifs         650
# 6753                gaming         632
# 9772             worldnews         599
# 7951                  news         563
# 4092        Showerthoughts         541
# 5423                   aww         529
# 7759     mildlyinteresting         525
# 7838                movies         524
# 4916                   WTF         487
# 2215                  IAmA         471
# 8328              politics         436
# 158          AdviceAnimals         428
# 9215            television         382
# 8709               science         381
# 6470     explainlikeimfive         376
# 8021           nottheonion         371
# 2665           LifeProTips         358
# 3033                 Music         354
# 9197            technology         338
# 2464                 Jokes         330
# 3287         OldSchoolCool         315
# 4559            The_Donald         310
# 9317                  tifu         300
# 7237     interestingasfuck         294
# 8969                 space         286
# 8208          pcmasterrace         278
# 6076                creepy         277
# 6173       dataisbeautiful         273
# 8993                sports         272
# 1804            Futurology         268
# 647     BlackPeopleTwitter         265
# 6610                  food         264
# 5680                 books         248
# 8252      photoshopbattles         240
# 4814         UpliftingNews         234
# 1180                   DIY         228
# 5380               atheism         224
# 9759              woahdude         222
# 2268  ImGoingToHellForThis         206
# 8505          reactiongifs         204
# 1465             EarthPorn         203
# 1374         Documentaries         202
# 4728        TumblrInAction         201
# 8306             pokemongo         200
# 1891          GetMotivated         197

# %% [markdown]
# <h2>Network Data</h2>

# %%
def MakeList(x):
    T = tuple(x)
    if len(T) > 1:
        return T
    else:
        return T[0]
f = {'subreddit':['count'], 'utc_stamp':[np.min,np.max],'submission': MakeList,'rnd_words': MakeList}
grouped = df.groupby(['user','subreddit']).agg(f)

# %%
grouped.head()
# Out:
#                                                                    rnd_words  \
#                                                                     MakeList
# user   subreddit
# -DEAD- 1200isplenty                               [Im, pikelet, call, Where]
#        ANormalDayInRussia           ([look, Someth, me, fake], [Look, fake])
#        Bonsai              ([it, see, make, Ill, I], [AKL], [know, Next, ...
#        Catan               [therefor, consequ, move, transfer, therefor, ...
#        DailyInkblot                           [eye, mustach, Clearli, coupl]
#
#                               utc_stamp                \
#                                    amin          amax
# user   subreddit
# -DEAD- 1200isplenty        1.474837e+09  1.474837e+09
#        ANormalDayInRussia  1.455337e+09  1.456432e+09
#        Bonsai              1.478570e+09  1.478635e+09
#        Catan               1.473304e+09  1.473304e+09
#        DailyInkblot        1.467325e+09  1.467325e+09
#
#                                                                   submission  \
#                                                                     MakeList
# user   subreddit
# -DEAD- 1200isplenty        [275, calories, for, this, stack, of, pancakes...
#        ANormalDayInRussia  ([Just, a, normal, sunday, drive], [Hell, of, ...
#        Bonsai              ([New, Zealand, National, Bonsai, show], [New,...
#        Catan                                                [Rule, question]
#        DailyInkblot                                              [6/30/2016]
#
#                           subreddit
#                               count
# user   subreddit
# -DEAD- 1200isplenty               1
#        ANormalDayInRussia         2
#        Bonsai                     3
#        Catan                      1
#        DailyInkblot               1

# %%
users = df.groupby('user')['user'].all()[0:1]
subreddits = list(df.groupby('subreddit')['subreddit'].nunique().keys())

# %%
G = nx.Graph()
loop_count = 0
for usr in users:
    if loop_count % 5 == 0:
        print (str(round(loop_count/len(users)*100,2)) + " % complete")
    loop_count = loop_count + 1
    for i,i_sub in enumerate(grouped['subreddit']['count'][usr].keys()):
        for j,j_sub in enumerate(grouped['subreddit']['count'][usr].keys()):
            if j > i:
                edge_id = '-'.join(sorted([i_sub,j_sub]))
                if G.has_edge(i_sub,j_sub) == False:
                    G.add_edge(i_sub,j_sub,{'source':i_sub,'target':j_sub,'weight':1,'id':edge_id})
                else:
                    G[i_sub][j_sub]['weight'] = G[i_sub][j_sub]['weight'] + 1
write_gexf(G,'reddit_network.gexf')
# Out:
# 0.0 % complete

# %% [markdown]
# <h3>Network Embedding</h3>

# %%
soup = BeautifulSoup(open("full_network.html"),"html.parser")

# %%
graph_cords = {}
nodes = soup.findAll('node')
for nd in nodes:
    crds = nd.find('viz:position')
    graph_cords[nd['label']] = {'x':crds['x'],'y':crds['y']}

# %%
graph_cords
# Out:
# {'greentea': {'x': '-1079.4105', 'y': '-557.6066'},
#  'mansformation': {'x': '341.6544', 'y': '64.417366'},
#  'WestboroBaptistChurch': {'x': '-438.81863', 'y': '1102.0286'},
#  'LAMeetUp': {'x': '334.2718', 'y': '544.791'},
#  'audioporn': {'x': '9.224994', 'y': '1026.8224'},
#  'NSFW_HTML5': {'x': '-401.39676', 'y': '-93.95492'},
#  'BaltimoreAndDCr4r': {'x': '1244.976', 'y': '1475.7104'},
#  'ben10porn': {'x': '-911.95526', 'y': '-221.7773'},
#  'pillowtalkaudio': {'x': '1102.1108', 'y': '89.998024'},
#  'greenday': {'x': '-1146.5533', 'y': '-743.1642'},
#  'ihatepeople': {'x': '74.87774', 'y': '-526.84'},
#  'Naples_FL': {'x': '938.6672', 'y': '-866.9762'},
#  'Objectivism': {'x': '66.53301', 'y': '613.54926'},
#  'LatinXXX': {'x': '-622.2127', 'y': '-301.65808'},
#  'Ubuntu': {'x': '496.1565', 'y': '-600.60297'},
#  'Cooking': {'x': '814.4535', 'y': '339.57394'},
#  'QueerTransmen': {'x': '28.513445', 'y': '107.74014'},
#  'PortlandRally': {'x': '-1211.1644', 'y': '350.41238'},
#  'nazi': {'x': '44.902054', 'y': '-508.81595'},
#  'counseling': {'x': '1106.8776', 'y': '-429.43396'},
#  'ZeroPunctuation': {'x': '-323.87054', 'y': '-252.76846'},
#  'ReverseRecipes': {'x': '732.7816', 'y': '154.25703'},
#  'plt': {'x': '444.1622', 'y': '-427.27023'},
#  'Punkskahardcore': {'x': '-601.85016', 'y': '134.8197'},
#  'Octavia': {'x': '506.40164', 'y': '1368.2947'},
#  'atheistgems': {'x': '-190.63492', 'y': '875.5855'},
#  'WisDan': {'x': '-1782.8904', 'y': '-212.09042'},
#  'GenderSanity': {'x': '11.828827', 'y': '161.02722'},
#  'CSUC': {'x': '549.8818', 'y': '527.8757'},
#  'Pictures': {'x': '50.326714', 'y': '-240.15994'},
#  'shittyaskhistory': {'x': '203.13861', 'y': '-18.170364'},
#  'cade': {'x': '-413.79733', 'y': '-419.10825'},
#  'fuckyea': {'x': '-756.74255', 'y': '712.26154'},
#  'SSBBWGW': {'x': '1196.8691', 'y': '766.94885'},
#  'MLHFIS': {'x': '251.18745', 'y': '1499.765'},
#  'Database': {'x': '-11.240158', 'y': '-8.054956'},
#  'explainlikeimfive': {'x': '1106.7888', 'y': '1394.0398'},
#  'HarrietPotter': {'x': '-1195.3917', 'y': '38.653248'},
#  'Val': {'x': '257.30417', 'y': '-392.15494'},
#  'veg': {'x': '994.925', 'y': '94.300026'},
#  'Xsmall': {'x': '-145.45839', 'y': '-877.37244'},
#  'india': {'x': '-484.5375', 'y': '-575.901'},
#  'oakland': {'x': '625.20715', 'y': '528.67114'},
#  'freecycle': {'x': '-52.849857', 'y': '45.18853'},
#  'toonporn': {'x': '255.87993', 'y': '1055.0846'},
#  'SANE': {'x': '-155.74615', 'y': '640.9459'},
#  'progether': {'x': '846.6256', 'y': '-473.142'},
#  '100sets': {'x': '1109.1288', 'y': '419.5146'},
#  'adultcontent': {'x': '688.3167', 'y': '-329.13245'},
#  'TodayIDrew': {'x': '-446.093', 'y': '-167.45557'},
#  'computers': {'x': '1459.0621', 'y': '233.10706'},
#  'tf2replays': {'x': '-1327.8923', 'y': '-596.2104'},
#  'Anticonsumption': {'x': '11.766325', 'y': '-13.133975'},
#  'mfw': {'x': '166.51244', 'y': '-185.72858'},
#  'monster_cocks': {'x': '-697.8675', 'y': '-581.7867'},
#  'Ioke': {'x': '468.61044', 'y': '-281.5207'},
#  'TorontoReserve': {'x': '330.149', 'y': '95.64642'},
#  'running': {'x': '472.8632', 'y': '314.74182'},
#  'TheBluePill': {'x': '4.653368', 'y': '205.1592'},
#  'RandomActsOfOralSex': {'x': '353.4152', 'y': '915.7854'},
#  'BritishPolitics': {'x': '-1121.1158', 'y': '354.64023'},
#  'wifeporn': {'x': '1017.25964', 'y': '392.03583'},
#  'FreewareIndex': {'x': '198.7142', 'y': '-100.60538'},
#  'steampony': {'x': '597.9097', 'y': '1454.6345'},
#  'israelexposed': {'x': '-242.58829', 'y': '414.56256'},
#  'amarillo': {'x': '556.9254', 'y': '402.5004'},
#  'steamsaledetectives': {'x': '-316.11777', 'y': '-379.60056'},
#  'BreastExpansion': {'x': '-703.0335', 'y': '-199.88936'},
#  'STREETFIGHTER2': {'x': '-288.79996', 'y': '-311.3804'},
#  '52weeksofcooking': {'x': '834.4465', 'y': '99.51243'},
#  'jerky': {'x': '847.3132', 'y': '332.40887'},
#  'thesimscontests': {'x': '2095.5007', 'y': '918.48486'},
#  'TodayIAte': {'x': '-1028.6147', 'y': '-260.0602'},
#  'boogie2988': {'x': '-1871.8337', 'y': '-389.43918'},
#  'powerpop': {'x': '-653.1457', 'y': '183.71306'},
#  'dubstep': {'x': '-845.0977', 'y': '288.9095'},
#  'gonewild': {'x': '-89.08369', 'y': '-68.020836'},
#  'scrodar': {'x': '-24.984367', 'y': '-493.02762'},
#  'Anxiety': {'x': '1160.2614', 'y': '-353.7801'},
#  'syriancivilwar': {'x': '-624.51324', 'y': '621.9642'},
#  'fursuitsex': {'x': '-258.53406', 'y': '-815.26294'},
#  'cincinnati': {'x': '945.45935', 'y': '1184.7465'},
#  'WingChun': {'x': '650.7644', 'y': '-65.77882'},
#  'trees': {'x': '-208.83107', 'y': '387.70352'},
#  'ifeelmyself': {'x': '-415.036', 'y': '-444.8099'},
#  'randomsexiness': {'x': '-228.91278', 'y': '-317.8134'},
#  'AnneHathaway': {'x': '-143.56377', 'y': '66.84665'},
#  'gaolbait': {'x': '210.07889', 'y': '-548.7953'},
#  'irc': {'x': '-208.70561', 'y': '-859.2563'},
#  'whoselineisitanyway': {'x': '-527.18243', 'y': '-82.221085'},
#  'SkincareAddiction': {'x': '-295.54663', 'y': '-598.2744'},
#  'pantyselling': {'x': '1682.2108', 'y': '-1386.1731'},
#  'Gifts': {'x': '921.5076', 'y': '1418.4497'},
#  'technology': {'x': '-157.98181', 'y': '184.4955'},
#  'police': {'x': '-915.7409', 'y': '-400.0761'},
#  'reddit.com': {'x': '-156.85423', 'y': '240.02573'},
#  'allthingsprotoss': {'x': '-664.70044', 'y': '-1075.4379'},
#  'scripting': {'x': '0.5015459', 'y': '-1241.0311'},
#  'africans': {'x': '164.9385', 'y': '-726.546'},
#  'qkme_transcriber': {'x': '1503.9388', 'y': '-431.1809'},
#  'bestofspacedicks': {'x': '-1441.8179', 'y': '-3.5190144'},
#  'conlangs': {'x': '-1255.1577', 'y': '-1135.848'},
#  'SantaMaria': {'x': '355.03412', 'y': '714.95776'},
#  'watersports': {'x': '-304.70288', 'y': '-721.5386'},
#  'DesignPorn': {'x': '266.77097', 'y': '-33.252266'},
#  'environment2': {'x': '-291.50055', 'y': '293.5575'},
#  'Bitcoincirclejerk': {'x': '-623.3379', 'y': '-164.25473'},
#  'glutenfreecooking': {'x': '1016.42725', 'y': '62.227093'},
#  'serialpodcast': {'x': '-507.717', 'y': '-797.4967'},
#  'darknetplanHW': {'x': '1445.1093', 'y': '330.37344'},
#  'Absinthe': {'x': '873.84106', 'y': '-172.44006'},
#  'whyamiwrong': {'x': '-81.599464', 'y': '209.96162'},
#  'manchester': {'x': '580.9587', 'y': '223.08746'},
#  'southland': {'x': '625.68994', 'y': '835.1083'},
#  'Ask_Politics': {'x': '-138.39981', 'y': '529.42456'},
#  'TF2LFT': {'x': '-1321.714', 'y': '-553.53265'},
#  'vancouver': {'x': '289.50076', 'y': '444.35602'},
#  'Faces': {'x': '-20.591373', 'y': '-803.57385'},
#  'AdviceAnimals': {'x': '-23.805586', 'y': '111.395615'},
#  'SuicideWatch': {'x': '829.0508', 'y': '-230.44368'},
#  'StrongAtheism': {'x': '-133.29483', 'y': '683.2839'},
#  'venturacounty': {'x': '660.56586', 'y': '722.3226'},
#  'seduction': {'x': '679.66644', 'y': '320.23508'},
#  'Nasty': {'x': '-553.5943', 'y': '-846.726'},
#  'ps3bc2': {'x': '-632.6655', 'y': '-1067.7163'},
#  'creepy': {'x': '255.66562', 'y': '-726.9266'},
#  'Purenudism': {'x': '465.07996', 'y': '388.19525'},
#  'computing': {'x': '137.7976', 'y': '127.473145'},
#  'listening2music': {'x': '-605.67487', 'y': '280.62006'},
#  'Cyberpunk': {'x': '-218.75502', 'y': '214.98549'},
#  'veronicamars': {'x': '-797.0834', 'y': '447.4843'},
#  'Minecraft': {'x': '-533.56793', 'y': '122.27032'},
#  'Republican': {'x': '-409.73196', 'y': '604.9482'},
#  'buttsex': {'x': '49.040203', 'y': '-681.192'},
#  'Survival': {'x': '297.27597', 'y': '221.14424'},
#  'WindyDay': {'x': '-17.811058', 'y': '-316.5498'},
#  'tf2gifts': {'x': '-1295.1329', 'y': '-578.3351'},
#  'FWEPP': {'x': '-186.0441', 'y': '134.7055'},
#  'psychedelicrock': {'x': '-635.2813', 'y': '217.34546'},
#  'grammar': {'x': '-935.61835', 'y': '-81.78197'},
#  'sandiegoents': {'x': '295.66476', 'y': '629.899'},
#  'bodyperfection': {'x': '41.8908', 'y': '372.76825'},
#  'illustrator': {'x': '-692.5084', 'y': '-1103.0789'},
#  'IntellectualReddit': {'x': '-162.35883', 'y': '532.18744'},
#  'PokemonROMhacks': {'x': '-737.61414', 'y': '-460.63696'},
#  'newsokur': {'x': '-203.72472', 'y': '-2645.3284'},
#  'unixporn': {'x': '525.8823', 'y': '-578.3164'},
#  'arabs': {'x': '-534.9477', 'y': '494.82452'},
#  'rdtclan': {'x': '-10.755862', 'y': '-201.78719'},
#  'askseddit': {'x': '274.78235', 'y': '404.85568'},
#  'gonewildaudio': {'x': '572.7327', 'y': '419.97324'},
#  'TeenMFA': {'x': '-202.68', 'y': '-307.74396'},
#  'SandersForPresident': {'x': '-1012.20557', 'y': '739.4453'},
#  'tf2au': {'x': '-1261.9937', 'y': '-600.9865'},
#  'fatpeoplestories': {'x': '-410.46408', 'y': '1.19151'},
#  'Reddit_ja': {'x': '-102.28035', 'y': '-2612.975'},
#  'Beekeeping': {'x': '83.348976', 'y': '17.700146'},
#  'VillagePorn': {'x': '202.44868', 'y': '24.032738'},
#  'Monk': {'x': '-1327.5898', 'y': '845.0206'},
#  'SelfSufficiency': {'x': '-675.88965', 'y': '-28.086985'},
#  'todayisaw': {'x': '-993.0851', 'y': '-257.47385'},
#  'treeschat': {'x': '249.05185', 'y': '645.6763'},
#  'VSTi': {'x': '-747.0762', 'y': '-128.27548'},
#  '52weeksofbaking': {'x': '824.38806', 'y': '128.88853'},
#  'Subredditfinder': {'x': '-628.355', 'y': '353.7174'},
#  'Orygun': {'x': '-1437.6456', 'y': '280.25977'},
#  'bestofwomen': {'x': '-226.97232', 'y': '119.741196'},
#  'Paranormal': {'x': '-1446.1163', 'y': '71.487'},
#  'Physiology': {'x': '-287.84042', 'y': '373.00174'},
#  'science': {'x': '-402.60196', 'y': '179.42871'},
#  'thinspo': {'x': '245.55566', 'y': '-1208.7217'},
#  'libertarianbestof': {'x': '-881.95953', 'y': '544.333'},
#  'Bestiality': {'x': '130.11745', 'y': '-644.85364'},
#  'RandomActsofDinner': {'x': '-1376.4435', 'y': '818.63684'},
#  'orangecounty': {'x': '629.1637', 'y': '782.4826'},
#  'mentalhealth': {'x': '936.86005', 'y': '-216.34285'},
#  'Humboldt': {'x': '753.7143', 'y': '775.37445'},
#  'Images': {'x': '178.6788', 'y': '-101.41172'},
#  'guro': {'x': '22.89986', 'y': '-544.4262'},
#  'AskSocialScience': {'x': '135.45894', 'y': '452.34177'},
#  'boysgonewild': {'x': '-660.8459', 'y': '-633.6548'},
#  'japanese4beginners': {'x': '-829.2084', 'y': '-431.2244'},
#  'skateboarding': {'x': '580.9673', 'y': '51.67431'},
#  'SexyShemales': {'x': '212.29704', 'y': '376.8915'},
#  'VintageAuto': {'x': '-697.11694', 'y': '-312.61664'},
#  'TOfilmmakers': {'x': '-831.04846', 'y': '-16.637825'},
#  'RightWingUK': {'x': '-982.5387', 'y': '738.00995'},
#  'tldr': {'x': '-160.79532', 'y': '193.96263'},
#  'gunk': {'x': '-788.8177', 'y': '340.0821'},
#  'LocationSound': {'x': '-228.26654', 'y': '159.47081'},
#  'seedswap': {'x': '-358.47568', 'y': '-189.37779'},
#  'OTonCharts': {'x': '-1050.0391', 'y': '142.58882'},
#  'reddithax': {'x': '-212.26404', 'y': '250.02078'},
#  'magicTCG': {'x': '751.1102', 'y': '-366.6325'},
#  'WorldWideNews': {'x': '-256.17148', 'y': '212.81233'},
#  'timetravel': {'x': '-565.9839', 'y': '565.5026'},
#  'mylittlewarhammer': {'x': '356.38297', 'y': '1598.6029'},
#  'erlang': {'x': '557.6272', 'y': '-356.7311'},
#  'Pennsylvania': {'x': '242.00655', 'y': '760.4406'},
#  'xsmallgirls': {'x': '-165.06982', 'y': '-186.63918'},
#  'men': {'x': '122.10872', 'y': '-240.26407'},
#  'openwrt': {'x': '694.2597', 'y': '-481.90515'},
#  'animemusic': {'x': '-986.11145', 'y': '7.850461'},
#  'Xsome': {'x': '-206.24577', 'y': '-130.56236'},
#  'analog': {'x': '-352.29156', 'y': '-596.05273'},
#  'sexypix': {'x': '-38.541183', 'y': '-1071.7417'},
#  'toronto': {'x': '52.21884', 'y': '-150.62233'},
#  'Connecticut': {'x': '-533.6798', 'y': '524.83307'},
#  'cats': {'x': '921.3748', 'y': '-723.3691'},
#  'Cynicalbrit': {'x': '-1952.9077', 'y': '-308.00018'},
#  'VintageLadyBoners': {'x': '-761.31396', 'y': '-641.02985'},
#  'letsplay': {'x': '-799.56604', 'y': '-406.45132'},
#  'ShittyTodayILearned': {'x': '957.4541', 'y': '-388.97076'},
#  'WestBank': {'x': '-96.151955', 'y': '-377.16342'},
#  'Cordcutting': {'x': '-631.7167', 'y': '-333.86716'},
#  'B_e_a_s_t': {'x': '-605.1644', 'y': '33.517624'},
#  'Atheism4all': {'x': '-57.798355', 'y': '780.84406'},
#  'sports': {'x': '580.15894', 'y': '-18.40699'},
#  'Orgasms': {'x': '-402.62192', 'y': '-513.71344'},
#  'AntiSRSCirclejerk': {'x': '500.07568', 'y': '89.67949'},
#  'dota2smut': {'x': '368.7119', 'y': '-760.17926'},
#  'ps3bf3': {'x': '-355.10437', 'y': '-679.42566'},
#  'video': {'x': '-386.96793', 'y': '-228.16875'},
#  'movies': {'x': '-331.63376', 'y': '231.2862'},
#  'grease': {'x': '1076.1819', 'y': '149.28915'},
#  'esperante': {'x': '-1178.9718', 'y': '-1189.6464'},
#  'GnuPG': {'x': '25.058327', 'y': '-230.72488'},
#  'MacroPorn': {'x': '247.24196', 'y': '1.4374404'},
#  'YouthRights': {'x': '14.341332', 'y': '205.11118'},
#  'AskScienceFiction': {'x': '-66.81197', 'y': '512.92596'},
#  '909': {'x': '727.6708', 'y': '716.7038'},
#  'TechLA': {'x': '823.2587', 'y': '720.5404'},
#  'ABDL': {'x': '-357.85464', 'y': '-537.655'},
#  'BBW_NSFW': {'x': '751.562', 'y': '-135.9678'},
#  'gayteenpics': {'x': '-387.9151', 'y': '-908.3712'},
#  'firstworldproblems': {'x': '-25.251501', 'y': '522.922'},
#  'Foodforthought': {'x': '822.6413', 'y': '448.38934'},
#  'programminghorror': {'x': '511.50006', 'y': '-458.67682'},
#  'LGBTOlder': {'x': '105.59611', 'y': '369.9661'},
#  'TOtrees': {'x': '-663.67914', 'y': '-51.394547'},
#  'VirginiaTech': {'x': '1014.3231', 'y': '564.79175'},
#  'software': {'x': '-226.19785', 'y': '-483.41757'},
#  'KansasCityChiefs': {'x': '451.00592', 'y': '153.67696'},
#  'chemistry': {'x': '-383.49072', 'y': '225.0002'},
#  'sleuths': {'x': '95.339035', 'y': '-100.85198'},
#  'entgaming': {'x': '-188.76764', 'y': '-211.29346'},
#  'Porn_Passes': {'x': '-618.7424', 'y': '-586.284'},
#  'scat': {'x': '-584.92444', 'y': '-782.76636'},
#  'miamidolphins': {'x': '864.45593', 'y': '-16.653559'},
#  'comiccon': {'x': '218.46426', 'y': '702.8164'},
#  'CharlestonSC': {'x': '863.4691', 'y': '410.54495'},
#  'computergraphics': {'x': '345.82303', 'y': '-6.5979323'},
#  'Found_Porn': {'x': '-212.7682', 'y': '-193.95016'},
#  'ClearBackblast': {'x': '-534.6071', 'y': '-446.16928'},
#  'JesusMyth': {'x': '-371.29147', 'y': '761.62445'},
#  'BostonSocialClub': {'x': '-739.76056', 'y': '407.09363'},
#  'ambientmusic': {'x': '-872.2603', 'y': '197.58266'},
#  'EatingForGeeks': {'x': '761.87616', 'y': '376.05804'},
#  'tongues': {'x': '24.497345', 'y': '-504.5479'},
#  'dirtyr4r': {'x': '501.37268', 'y': '1066.8472'},
#  'rethinktheleaf': {'x': '427.06583', 'y': '790.41907'},
#  'Transportation': {'x': '-27.075357', 'y': '171.65862'},
#  'ColdWarPosters': {'x': '9.945698', 'y': '-100.463196'},
#  'AlternativeHealth': {'x': '864.5912', 'y': '532.8031'},
#  'Egalitarianism': {'x': '265.95065', 'y': '-141.56094'},
#  '1000words': {'x': '-84.187614', 'y': '-149.95686'},
#  'anarchocommunism': {'x': '-542.7658', 'y': '870.2061'},
#  'gaystorylines': {'x': '-513.1553', 'y': '139.81479'},
#  'Pokemonexchange': {'x': '-975.1275', 'y': '-30.908737'},
#  'bisexualadults': {'x': '220.81952', 'y': '479.76553'},
#  'AtheistMusic': {'x': '-573.61926', 'y': '522.1948'},
#  'blasphemy': {'x': '89.458374', 'y': '-614.6506'},
#  'SimStories': {'x': '2257.1772', 'y': '954.0701'},
#  'Protestantism': {'x': '-832.1722', 'y': '739.34576'},
#  'AlexandriaDeberry': {'x': '199.26607', 'y': '-1062.468'},
#  'menshealth': {'x': '-7.3106136', 'y': '-61.980385'},
#  'hardware': {'x': '233.15959', 'y': '-228.20284'},
#  'newzealand': {'x': '-479.2809', 'y': '-931.546'},
#  'truetf2': {'x': '-1165.462', 'y': '-723.15936'},
#  'atheistsinfoxholes': {'x': '-269.0764', 'y': '754.0512'},
#  'asianart': {'x': '-961.6345', 'y': '-1054.4259'},
#  'NSFWGames': {'x': '-453.46436', 'y': '-971.2718'},
#  'porno_nsfw': {'x': '-187.61104', 'y': '-170.40086'},
#  'AnimalIntelligence': {'x': '576.1026', 'y': '-640.09863'},
#  'violentacrez': {'x': '10.469819', 'y': '-360.41898'},
#  'bitcoinaustralia': {'x': '-828.6592', 'y': '-1608.5541'},
#  'RamaOne': {'x': '-586.9744', 'y': '684.54626'},
#  'RandomActsOfGaming': {'x': '-361.6382', 'y': '-304.69095'},
#  'traps': {'x': '283.4979', 'y': '407.7294'},
#  'sick': {'x': '4.4279833', 'y': '-472.8478'},
#  'findareddit': {'x': '-299.6244', 'y': '157.27628'},
#  'HumanBody': {'x': '-532.4217', 'y': '779.1819'},
#  'masseffect': {'x': '-746.401', 'y': '-429.47754'},
#  'penismeasured': {'x': '-461.73843', 'y': '-653.42444'},
#  'fluid': {'x': '-353.72897', 'y': '257.692'},
#  'Totallyspiesrule34': {'x': '237.47873', 'y': '474.772'},
#  'ElectionActivism': {'x': '-84.49145', 'y': '197.6737'},
#  'yiff': {'x': '-198.26999', 'y': '429.0458'},
#  'amazonbestsellers': {'x': '1392.5269', 'y': '99.30499'},
#  'opendirectories': {'x': '341.3157', 'y': '-169.81796'},
#  'JesusPorn': {'x': '122.21018', 'y': '-489.55875'},
#  'TeaPorn': {'x': '779.13556', 'y': '125.65896'},
#  'fibro': {'x': '813.4017', 'y': '32.44462'},
#  'rightist': {'x': '-1071.1735', 'y': '499.85568'},
#  'BaconBits': {'x': '-1889.6919', 'y': '-608.6116'},
#  'IndianFood': {'x': '705.39', 'y': '234.54724'},
#  'MusicNews': {'x': '-775.7118', 'y': '223.0031'},
#  'GreatApes': {'x': '-268.7801', 'y': '-203.36082'},
#  'AppTalk': {'x': '47.223366', 'y': '-37.56922'},
#  'AskGreypoos': {'x': '1240.5613', 'y': '1291.8088'},
#  'exchristian': {'x': '-175.14568', 'y': '827.12756'},
#  'TodayIdreamed': {'x': '-1077.555', 'y': '-273.96237'},
#  'SouthDakota': {'x': '140.68143', 'y': '762.1959'},
#  'LV426': {'x': '-378.05612', 'y': '391.93533'},
#  'HypnoHookup': {'x': '-448.0923', 'y': '-1503.7139'},
#  'politics2': {'x': '-494.7335', 'y': '691.0802'},
#  'KerbalSpaceProgram': {'x': '-341.25143', 'y': '-334.38873'},
#  'tonightsdinner': {'x': '1021.36224', 'y': '129.25713'},
#  'tranarchism': {'x': '172.02936', 'y': '501.07364'},
#  'LoLScrimSetup': {'x': '-763.7147', 'y': '-869.7712'},
#  'Clojure': {'x': '621.74396', 'y': '-425.44064'},
#  'mylittlefortress': {'x': '311.40164', 'y': '1348.3285'},
#  'randomactsofcoffee': {'x': '-1241.1112', 'y': '814.0577'},
#  'youthparticipation': {'x': '94.63637', 'y': '475.46667'},
#  'kickstarter': {'x': '-978.8979', 'y': '387.17194'},
#  'waterporn': {'x': '-232.93974', 'y': '-223.51344'},
#  'C_Programming': {'x': '654.18115', 'y': '-413.57797'},
#  'musicians': {'x': '-679.9073', 'y': '333.8315'},
#  'Disneyland': {'x': '530.0708', 'y': '826.0712'},
#  'Cinema4D': {'x': '631.48535', 'y': '958.6842'},
#  'Advice': {'x': '199.66307', 'y': '475.6909'},
#  'TributeTogether': {'x': '259.73465', 'y': '534.82074'},
#  'trees_IRL': {'x': '25.900291', 'y': '-120.427284'},
#  'todayilearned_jp': {'x': '-182.01653', 'y': '-2600.3567'},
#  'SRSBusiness': {'x': '61.77577', 'y': '422.04678'},
#  'tgirlass': {'x': '191.70473', 'y': '433.716'},
#  'dicks': {'x': '-651.34717', 'y': '-720.6865'},
#  'ProgrammingBuddies': {'x': '553.30206', 'y': '-394.62714'},
#  'Lazy_dun_gooder': {'x': '-437.76324', 'y': '575.53125'},
#  'psychotherapy': {'x': '920.32385', 'y': '-272.46182'},
#  'germany': {'x': '-596.9609', 'y': '-75.345314'},
#  'Learning': {'x': '229.96655', 'y': '-253.29979'},
#  'SexWithDogs': {'x': '-316.38657', 'y': '-683.2372'},
#  'VA_Saved': {'x': '150.93272', 'y': '-282.70044'},
#  'modsmack': {'x': '51.752148', 'y': '-493.6986'},
#  'ludology': {'x': '-621.92285', 'y': '-434.365'},
#  'AndroidGameDeals': {'x': '-314.78522', 'y': '-408.9494'},
#  'ExposurePorn': {'x': '-619.56256', 'y': '-377.97586'},
#  'SketchDaily': {'x': '-841.95355', 'y': '-500.33658'},
#  'girlsmasturbating': {'x': '-549.3686', 'y': '-696.1394'},
#  'cripplingorgasm': {'x': '-528.5854', 'y': '-650.49603'},
#  'archlinux': {'x': '201.24696', 'y': '-227.6476'},
#  'cheats': {'x': '590.5203', 'y': '-455.94177'},
#  'opencatholics': {'x': '-150.34123', 'y': '609.79755'},
#  'exmuslim': {'x': '-177.64499', 'y': '669.39905'},
#  'lpmc': {'x': '397.5956', 'y': '-231.34991'},
#  'MLPvids': {'x': '365.55054', 'y': '1476.3414'},
#  'davidfosterwallace': {'x': '235.76941', 'y': '-191.46973'},
#  'django': {'x': '1003.6945', 'y': '-705.9846'},
#  'tahoe': {'x': '379.93762', 'y': '496.12338'},
#  'fanfic': {'x': '-335.28802', 'y': '375.54462'},
#  'paleonews': {'x': '-469.95084', 'y': '192.86552'},
#  'food': {'x': '1069.1881', 'y': '200.6862'},
#  'GreyAutumnalSongs': {'x': '-783.90247', 'y': '148.23137'},
#  'futanari': {'x': '-260.08868', 'y': '-538.6574'},
#  'longboarding': {'x': '672.7498', 'y': '-40.02543'},
#  'phpscripts': {'x': '410.56158', 'y': '-761.8317'},
#  'libertarianmeme': {'x': '-230.38345', 'y': '535.7564'},
#  'woweconomy': {'x': '11.896721', 'y': '-1317.8038'},
#  'LOLDyrus': {'x': '-678.5374', 'y': '-879.2293'},
#  'RandomDeclarations': {'x': '-647.5783', 'y': '563.01715'},
#  'bashtricks': {'x': '418.00644', 'y': '-147.25293'},
#  'CSUS': {'x': '497.0558', 'y': '516.369'},
#  'wikipedia': {'x': '-193.65652', 'y': '1528.9033'},
#  'interview': {'x': '-93.473335', 'y': '261.64493'},
#  'yaoi': {'x': '-583.1267', 'y': '-254.75623'},
#  'TributeMe': {'x': '-1986.7603', 'y': '1096.6163'},
#  'kayakotto': {'x': '593.4637', 'y': '-129.9811'},
#  'RandomActsOfSupport': {'x': '-1246.2427', 'y': '845.62555'},
#  'criticism': {'x': '-590.2602', 'y': '318.18912'},
#  'deep_ecology': {'x': '-976.04425', 'y': '607.0112'},
#  '911truth': {'x': '-732.6081', 'y': '1226.051'},
#  'ChaoticMonki': {'x': '-1892.3774', 'y': '-307.20837'},
#  'BronyHate': {'x': '609.1934', 'y': '1325.4915'},
#  'MW2': {'x': '-344.78186', 'y': '-281.27182'},
#  'ElPaso': {'x': '724.6697', 'y': '91.78576'},
#  'Playdate': {'x': '-512.0663', 'y': '-358.8771'},
#  'BonersInPublic': {'x': '-804.06775', 'y': '-666.0792'},
#  'torontodating': {'x': '-672.8224', 'y': '-3.5721097'},
#  'Photobucketplunder': {'x': '151.54193', 'y': '18.1974'},
#  'worldphotography': {'x': '-322.0124', 'y': '212.91785'},
#  'Modesto': {'x': '407.21188', 'y': '587.75854'},
#  'TheNarutoWorld': {'x': '-638.517', 'y': '-113.28499'},
#  'tipofmypenis': {'x': '-523.7748', 'y': '-529.1846'},
#  'roguelikedev': {'x': '679.35455', 'y': '-1430.0363'},
#  'drunk_ja': {'x': '-134.18248', 'y': '-2625.9001'},
#  'RealEstateTechnology': {'x': '870.3017', 'y': '975.54095'},
#  'Homebrewing': {'x': '898.3098', 'y': '-10.595863'},
#  'wowloot': {'x': '-156.42438', 'y': '-1314.5817'},
#  'taoism': {'x': '-245.63179', 'y': '581.6367'},
#  'nerdcubed': {'x': '-1828.3357', 'y': '-373.85687'},
#  'carlhprogramming': {'x': '349.0412', 'y': '-277.30014'},
#  'LearnHowItWorks': {'x': '-333.8558', 'y': '127.22208'},
#  'AmericanGovernment': {'x': '-344.51428', 'y': '700.8325'},
#  'fratdeals': {'x': '455.86978', 'y': '443.9914'},
#  'MlpXbox': {'x': '565.01556', 'y': '1567.14'},
#  'omegle': {'x': '-252.78621', 'y': '-383.35983'},
#  'canyouexplainthat': {'x': '-785.08307', 'y': '626.22205'},
#  'simssocial': {'x': '2104.097', 'y': '884.071'},
#  'RuinedOrgasms': {'x': '-880.37964', 'y': '-156.39647'},
#  'ProjectReddit': {'x': '373.00955', 'y': '64.72182'},
#  'exmormonfffuuuu': {'x': '-608.66754', 'y': '785.22534'},
#  'randimgur': {'x': '480.12308', 'y': '132.9805'},
#  'Montana': {'x': '107.88786', 'y': '916.9938'},
#  'dailykanji': {'x': '-816.4004', 'y': '-372.3924'},
#  'UCSD': {'x': '624.53564', 'y': '737.1873'},
#  'nil': {'x': '216.82022', 'y': '818.2414'},
#  'gayanime': {'x': '-650.91907', 'y': '-174.19826'},
#  'worldnews': {'x': '-455.61612', 'y': '430.11438'},
#  'bestofnetflix': {'x': '-638.506', 'y': '756.4103'},
#  'AntiPOZi': {'x': '-416.39786', 'y': '-676.5862'},
#  'Elephant6': {'x': '-876.07556', 'y': '278.85696'},
#  'AvatarPorn': {'x': '-597.65326', 'y': '-342.66772'},
#  'WomenOfColour': {'x': '-214.4138', 'y': '-210.52612'},
#  'JDorama': {'x': '-925.4935', 'y': '-1001.27203'},
#  'episodehub': {'x': '-692.83484', 'y': '565.4219'},
#  'firespin': {'x': '-1060.7543', 'y': '-2250.559'},
#  'Cleveland': {'x': '1117.264', 'y': '1273.8801'},
#  'PenmanshipPorn': {'x': '895.6921', 'y': '-119.592224'},
#  'egalitarian': {'x': '632.54584', 'y': '343.27988'},
#  'prop19': {'x': '-132.72118', 'y': '559.41095'},
#  'randomactsofpokemon': {'x': '-1279.4102', 'y': '637.15826'},
#  'Colts': {'x': '784.36926', 'y': '29.005964'},
#  'Damn_Bored': {'x': '-801.1843', 'y': '12.658531'},
#  'thousandoaks': {'x': '516.22015', 'y': '729.10095'},
#  'InfrastructurePorn': {'x': '233.1856', 'y': '28.87482'},
#  'Buddhism': {'x': '68.25214', 'y': '786.27985'},
#  'shorthairedhotties': {'x': '201.78989', 'y': '-122.536964'},
#  'HailCorporate': {'x': '-1140.452', 'y': '366.7302'},
#  'AnimalCrossing': {'x': '-2077.7249', 'y': '-455.81616'},
#  'NCAL': {'x': '794.4377', 'y': '782.3151'},
#  'blackflag': {'x': '-303.9864', 'y': '575.73096'},
#  'agnostic': {'x': '-255.88518', 'y': '979.6401'},
#  'ShokugekiNoSoma': {'x': '-826.4137', 'y': '-276.15042'},
#  'RosarioVampire': {'x': '-1080.7814', 'y': '-197.01193'},
#  'TalesFromRetail': {'x': '-1246.2485', 'y': '2180.8618'},
#  'MyCherryCrush': {'x': '-209.78958', 'y': '-50.323406'},
#  'EngorgedVeinyBreasts': {'x': '-644.7923', 'y': '827.8711'},
#  'UofT': {'x': '-609.3819', 'y': '-41.55275'},
#  'RealEstate': {'x': '1315.6005', 'y': '1368.1947'},
#  'Judaism': {'x': '-203.44745', 'y': '595.3332'},
#  'UnusualArt': {'x': '-649.771', 'y': '353.37973'},
#  'Efficiency': {'x': '-102.03064', 'y': '-60.40762'},
#  'pathofexile': {'x': '-1057.8599', 'y': '-124.14648'},
#  'Humanist': {'x': '-414.1527', 'y': '860.38916'},
#  'teen_girls': {'x': '-49.45076', 'y': '-933.95056'},
#  'BigTitsAlert': {'x': '-353.14453', 'y': '-28.55173'},
#  'gfur': {'x': '-273.7059', 'y': '45.153492'},
#  'Permaculture': {'x': '-111.88179', 'y': '499.2003'},
#  'CuteAsianGirls': {'x': '-1303.539', 'y': '317.3296'},
#  'EA_NHL': {'x': '33.999134', 'y': '-176.10612'},
#  'Design': {'x': '-332.84912', 'y': '259.7697'},
#  'gallopfrey': {'x': '428.79865', 'y': '1470.9073'},
#  'peyups': {'x': '1194.6398', 'y': '957.5431'},
#  'ImaginaryTechnology': {'x': '-166.92096', 'y': '146.0312'},
#  'Recettear': {'x': '-965.99677', 'y': '-137.61642'},
#  'malemodels': {'x': '-0.32543337', 'y': '-562.62164'},
#  'nudist': {'x': '1139.4214', 'y': '677.95264'},
#  'AnimatedGIF': {'x': '-82.81588', 'y': '-760.4656'},
#  'WomenInUniform': {'x': '-185.44797', 'y': '-434.03964'},
#  'osc': {'x': '-695.5869', 'y': '675.2561'},
#  'Svenska': {'x': '-1263.9612', 'y': '-2199.6248'},
#  'WedgieGirls': {'x': '-439.61835', 'y': '-908.3828'},
#  'shittyaskscience': {'x': '318.73242', 'y': '-51.83008'},
#  'Charcuterie': {'x': '989.82275', 'y': '225.59912'},
#  'Jab': {'x': '-962.433', 'y': '-904.5725'},
#  'AskProgramming': {'x': '626.13934', 'y': '-472.2789'},
#  'Meditation': {'x': '108.77206', 'y': '1256.4174'},
#  'DubstepandSimilar': {'x': '-901.87164', 'y': '144.9929'},
#  'whatsthisbird': {'x': '-1277.7955', 'y': '661.4048'},
#  'Denton': {'x': '634.25934', 'y': '292.0615'},
#  'YogscastHannah': {'x': '-1832.7048', 'y': '-324.5133'},
#  'lompoc': {'x': '404.44296', 'y': '721.81635'},
#  'frenchmaid': {'x': '274.70044', 'y': '-456.03406'},
#  'Spaceexploration': {'x': '-858.62213', 'y': '-54.56983'},
#  'SanDiegoJobs': {'x': '350.4095', 'y': '625.21216'},
#  'impoliteconversation': {'x': '-333.4109', 'y': '636.7786'},
#  'nuclear': {'x': '-321.30518', 'y': '180.76526'},
#  'IBelieveAMA': {'x': '-139.79373', 'y': '589.00726'},
#  'USC': {'x': '494.6013', 'y': '566.9951'},
#  'storiesofdreams': {'x': '-567.386', 'y': '-72.822525'},
#  'thecane': {'x': '392.56555', 'y': '1328.2301'},
#  'acturnips': {'x': '-2065.014', 'y': '-523.44855'},
#  'ClopClop': {'x': '254.69301', 'y': '704.40594'},
#  'crypto': {'x': '565.8796', 'y': '-149.10997'},
#  'androidtablets': {'x': '382.30023', 'y': '-923.1081'},
#  'LetsChat': {'x': '413.2627', 'y': '882.6483'},
#  'MLPphotoshopbattles': {'x': '365.7033', 'y': '1503.9788'},
#  'slackerrecipes': {'x': '1068.9482', 'y': '271.34155'},
#  'Biomed': {'x': '-261.50558', 'y': '277.84354'},
#  'WorstOfSRS': {'x': '-341.30066', 'y': '389.5203'},
#  'autotune': {'x': '-1364.3711', 'y': '97.08138'},
#  'transgender': {'x': '92.71539', 'y': '184.7772'},
#  'UQreddit': {'x': '434.15955', 'y': '645.14667'},
#  'trumpet': {'x': '-664.5348', 'y': '234.39317'},
#  'texas': {'x': '160.43633', 'y': '714.83734'},
#  '100pushups': {'x': '446.84082', 'y': '371.41324'},
#  'r4r': {'x': '975.89594', 'y': '1439.452'},
#  'DailyLinks': {'x': '123.81636', 'y': '-594.83435'},
#  'AustralianPolitics': {'x': '-912.74286', 'y': '604.023'},
#  'gonewild_gif': {'x': '-412.41452', 'y': '-152.75058'},
#  'castiron': {'x': '1153.7479', 'y': '262.30676'},
#  'MilitaryGoneWild': {'x': '471.1712', 'y': '108.05286'},
#  'atheistparents': {'x': '-229.75912', 'y': '823.1883'},
#  'PerfectTits': {'x': '-268.46777', 'y': '-54.074257'},
#  'LoLChampConcepts': {'x': '-695.2331', 'y': '-848.3759'},
#  'NSFW_GAY': {'x': '-141.55798', 'y': '6.836379'},
#  'gayporn': {'x': '-463.92758', 'y': '-850.8699'},
#  'RECrowdfunding': {'x': '1318.931', 'y': '1334.3014'},
#  'pornography': {'x': '-614.04626', 'y': '-130.48718'},
#  'gaybros': {'x': '-204.82642', 'y': '50.050793'},
#  'XXX_Animated_Gifs': {'x': '771.6854', 'y': '302.46017'},
#  'ateismo': {'x': '-172.54308', 'y': '1044.233'},
#  'JapanSoc': {'x': '-967.07434', 'y': '-551.5798'},
#  'PublicLands': {'x': '-436.2097', 'y': '281.07007'},
#  'WWTT': {'x': '-56.052555', 'y': '-252.48976'},
#  'libredesign': {'x': '401.1184', 'y': '-609.9565'},
#  'americanpirateparty': {'x': '-538.0202', 'y': '753.5165'},
#  'bubbling': {'x': '287.8303', 'y': '-658.5133'},
#  'arduino': {'x': '-279.64548', 'y': '-620.3802'},
#  'PornOverlords': {'x': '292.90817', 'y': '26.804062'},
#  'pinkshoes': {'x': '85.06287', 'y': '-478.22864'},
#  'photojournalism': {'x': '-265.1672', 'y': '-165.357'},
#  'redditchan': {'x': '445.145', 'y': '-196.59329'},
#  'atheistinfo': {'x': '-24.512537', 'y': '920.0649'},
#  'Ancientknowledge': {'x': '-915.4988', 'y': '1247.2654'},
#  'RoomPorn': {'x': '230.20027', 'y': '46.37167'},
#  'gothsluts': {'x': '112.99953', 'y': '-559.148'},
#  'Piratebox': {'x': '1347.9763', 'y': '137.9702'},
#  'ipm': {'x': '-844.64514', 'y': '28.990086'},
#  'Palestine': {'x': '-278.5055', 'y': '460.30176'},
#  'TF2Unusuals': {'x': '-1176.1014', 'y': '-683.3607'},
#  'booty': {'x': '739.6504', 'y': '-314.79904'},
#  'CuteFemaleCorpses': {'x': '620.32184', 'y': '-792.42926'},
#  'HardcoreHentai': {'x': '-573.1653', 'y': '883.18567'},
#  'cookingvideos': {'x': '759.0328', 'y': '199.61873'},
#  'redditoroftheday': {'x': '-204.8404', 'y': '230.1313'},
#  'new_right': {'x': '-466.1372', 'y': '547.2343'},
#  'twilightsparkle': {'x': '390.30463', 'y': '1365.2742'},
#  'metalgearsolid': {'x': '94.12705', 'y': '-909.6658'},
#  'starcraft': {'x': '-449.94843', 'y': '-511.27042'},
#  'websec': {'x': '48.851013', 'y': '74.74797'},
#  'I_am_the_first_one': {'x': '-645.03046', 'y': '321.73935'},
#  'Dreams': {'x': '-938.77216', 'y': '-330.39066'},
#  'anonymous': {'x': '582.5045', 'y': '-164.18011'},
#  'lego': {'x': '-1065.2109', 'y': '433.6332'},
#  'ladybonersgw': {'x': '-189.17694', 'y': '-99.53539'},
#  'WritingPrompts': {'x': '-563.2055', 'y': '106.090805'},
#  'secularbuddhism': {'x': '-148.51718', 'y': '1083.0573'},
#  'trailmeals': {'x': '858.23016', 'y': '434.03656'},
#  'SRSArt': {'x': '272.466', 'y': '53.89244'},
#  'triphop': {'x': '-561.61774', 'y': '160.22926'},
#  'windowshots': {'x': '-107.2897', 'y': '-11.085843'},
#  'lalna': {'x': '-1822.9874', 'y': '-460.16412'},
#  'IndieGaming': {'x': '-483.8154', 'y': '-312.01828'},
#  'OpenChristian': {'x': '-273.3747', 'y': '1138.0027'},
#  'Adgeek': {'x': '-428.89816', 'y': '107.87129'},
#  'gonewildfriends': {'x': '-294.78918', 'y': '53.60035'},
#  'pecker': {'x': '-580.10016', 'y': '-644.2724'},
#  'CGPGrey': {'x': '-1908.8462', 'y': '-265.76477'},
#  'RadicalFeminism': {'x': '122.17862', 'y': '34.612244'},
#  'dirtykik': {'x': '362.1846', 'y': '-32.08549'},
#  'jrock': {'x': '-721.4158', 'y': '34.448414'},
#  'CBD': {'x': '254.8835', 'y': '-49.2785'},
#  'todayiwatched': {'x': '-570.83606', 'y': '-105.3732'},
#  'cocaine': {'x': '725.45935', 'y': '479.5196'},
#  'opensourcegames': {'x': '-298.251', 'y': '-652.1417'},
#  'HellenicPolytheism': {'x': '-126.79752', 'y': '635.4061'},
#  'redheads': {'x': '939.23883', 'y': '779.5418'},
#  'wicked_edge': {'x': '-2119.214', 'y': '-200.75597'},
#  'BlackAtheism': {'x': '-280.29343', 'y': '594.35114'},
#  'talks': {'x': '-435.79285', 'y': '740.34375'},
#  'opengov': {'x': '-109.001274', 'y': '381.25793'},
#  'idolmaster': {'x': '-734.341', 'y': '-67.258865'},
#  'ClassicRedditThreads': {'x': '-148.94249', 'y': '386.36734'},
#  '4hourbodyslowcarb': {'x': '759.29', 'y': '216.24963'},
#  'UkrainianConflict': {'x': '-492.22394', 'y': '71.01864'},
#  'RedDeer': {'x': '-863.5828', 'y': '-1082.1205'},
#  'ShittyPoetry': {'x': '1004.67206', 'y': '-343.4866'},
#  'HigherEd': {'x': '309.8741', 'y': '432.55048'},
#  'XXX_GIF': {'x': '-687.57086', 'y': '-173.52496'},
#  'UpperCanada': {'x': '65.916885', 'y': '-154.37051'},
#  'web_dev_help': {'x': '127.901405', 'y': '47.66194'},
#  'mylittleicons': {'x': '430.6683', 'y': '1308.6162'},
#  'Bulge': {'x': '-728.044', 'y': '-708.9339'},
#  'alife': {'x': '-130.01062', 'y': '164.48784'},
#  'brony': {'x': '-1244.9149', 'y': '523.2683'},
#  'formula1': {'x': '655.2438', 'y': '21.830387'},
#  'stockings': {'x': '-287.61795', 'y': '-755.3466'},
#  'rule34': {'x': '-426.77725', 'y': '-356.01'},
#  'mylittleandysonic1': {'x': '195.46086', 'y': '1431.5631'},
#  'Greypo': {'x': '1287.1407', 'y': '1334.2817'},
#  'LAforHire': {'x': '348.21252', 'y': '569.0769'},
#  'SRSBooks': {'x': '305.30527', 'y': '138.06781'},
#  'MegaVideos': {'x': '-1539.3683', 'y': '-1210.862'},
#  'hylian': {'x': '-884.9137', 'y': '-541.57544'},
#  'DCcomics': {'x': '-643.28033', 'y': '660.8499'},
#  'gaypornhunters': {'x': '-484.78833', 'y': '-273.70462'},
#  'Inventions': {'x': '-1061.7606', 'y': '360.43585'},
#  'autodidactic': {'x': '301.8399', 'y': '-209.323'},
#  'TeamFortress2': {'x': '-368.85214', 'y': '-405.55997'},
#  'CA4NeoProgs': {'x': '-11.51926', 'y': '665.4655'},
#  'cheerleaders': {'x': '304.3149', 'y': '-687.61334'},
#  'starbound': {'x': '-345.0201', 'y': '-239.26462'},
#  'TheMakingOf': {'x': '-331.32074', 'y': '271.20853'},
#  'asseffect': {'x': '-971.8517', 'y': '-104.184'},
#  'TheLastAirbender': {'x': '-462.53058', 'y': '610.2044'},
#  'assinthong': {'x': '-70.51767', 'y': '-159.99153'},
#  'GirlsInTightShirts': {'x': '2042.8157', 'y': '919.16797'},
#  'korea': {'x': '-101.817154', 'y': '-589.3351'},
#  'themvoices': {'x': '-601.3737', 'y': '222.64644'},
#  'mylittleWTF': {'x': '477.4659', 'y': '1474.227'},
#  'gaygentlemanboners': {'x': '-629.6723', 'y': '-683.86316'},
#  'homebrew': {'x': '940.04224', 'y': '487.8933'},
#  'nsfw_gfys': {'x': '-242.04198', 'y': '-64.836784'},
#  'AmericanJewishPower': {'x': '-390.567', 'y': '472.47684'},
#  'subatomic': {'x': '-354.77505', 'y': '393.47394'},
#  'britishproblems': {'x': '-1557.0385', 'y': '519.77026'},
#  'DealsReddit': {'x': '675.9784', 'y': '-433.9259'},
#  'bimbofetish': {'x': '732.07056', 'y': '-841.66583'},
#  'TwinGirls': {'x': '-1254.7471', 'y': '-0.2991018'},
#  'Mylittlenosleep': {'x': '444.12006', 'y': '1424.1606'},
#  'vexillology': {'x': '3.787559', 'y': '-54.75499'},
#  'hipsters': {'x': '1000.997', 'y': '594.8397'},
#  'mylittlehuman': {'x': '268.66333', 'y': '1586.3206'},
#  'FoodPorn': {'x': '808.8366', 'y': '79.7214'},
#  'nippleslip': {'x': '351.49658', 'y': '387.2994'},
#  'energy': {'x': '-1119.1132', 'y': '131.7175'},
#  'SRSFeminism': {'x': '41.37049', 'y': '689.2511'},
#  'PhilosophyofMind': {'x': '34.240646', 'y': '473.1811'},
#  'mango': {'x': '953.3185', 'y': '365.5754'},
#  'HotRapeStories': {'x': '-509.8151', 'y': '638.9579'},
#  'apple': {'x': '226.47816', 'y': '-168.37627'},
#  'JapaneseFood': {'x': '679.0576', 'y': '236.08098'},
#  'massachusetts': {'x': '-395.7366', 'y': '437.6877'},
#  'taco': {'x': '944.106', 'y': '114.27584'},
#  'AnimalsBeingConfused': {'x': '557.2244', 'y': '-600.6964'},
#  'facebookatheism': {'x': '-154.26973', 'y': '879.91583'},
#  'youtube': {'x': '-515.2922', 'y': '-287.78827'},
#  'GirlsHumpingThings': {'x': '-132.30803', 'y': '42.930916'},
#  'cookwithbeer': {'x': '933.36975', 'y': '79.65686'},
#  'BostonBruins': {'x': '669.2243', 'y': '342.68518'},
#  'invest': {'x': '-1138.1082', 'y': '160.51854'},
#  'mashups': {'x': '-863.89465', 'y': '70.34853'},
#  'Kawaii': {'x': '-1100.1089', 'y': '-353.7711'},
#  'DebateAnAtheist': {'x': '-409.69788', 'y': '767.47156'},
#  'videos': {'x': '-236.64087', 'y': '-337.82'},
#  'r4rplus': {'x': '300.05936', 'y': '608.256'},
#  'TransSpace': {'x': '221.32841', 'y': '244.15468'},
#  'ArabicAtheism': {'x': '-285.42307', 'y': '926.4364'},
#  'TheSims3FamilyStories': {'x': '1951.9135', 'y': '898.15857'},
#  'SeriouslyLuna': {'x': '630.5754', 'y': '1388.0367'},
#  'singularity': {'x': '-667.9362', 'y': '1325.8881'},
#  'achappyhome': {'x': '-1941.0387', 'y': '-410.31873'},
#  'HardcoreSex': {'x': '-128.5771', 'y': '-65.01699'},
#  'CityOfLA': {'x': '405.00864', 'y': '477.85245'},
#  'HealthyRecipe': {'x': '1265.5438', 'y': '280.40677'},
#  'fence': {'x': '322.9909', 'y': '-342.9698'},
#  'carporn': {'x': '13.844711', 'y': '-79.01958'},
#  'AsianPorn': {'x': '-889.62744', 'y': '59.507225'},
#  'GPGpractice': {'x': '81.41344', 'y': '-234.52188'},
#  'cock': {'x': '-736.83813', 'y': '-671.2544'},
#  'love2d': {'x': '-83.01683', 'y': '-258.50458'},
#  'Ju_Jutsu': {'x': '-387.03458', 'y': '-662.61804'},
#  'exSistersinZion': {'x': '-514.4079', 'y': '1064.7655'},
#  'uncharted3': {'x': '-340.67758', 'y': '-382.53006'},
#  'ParanormalEncounters': {'x': '-1477.1796', 'y': '131.21532'},
#  'NewAgeAtheist': {'x': '-55.739567', 'y': '733.84515'},
#  'horsecommunity': {'x': '-77.9618', 'y': '457.73734'},
#  'OCTrees': {'x': '415.16223', 'y': '768.81537'},
#  'RepublicOfAtheism': {'x': '-299.92426', 'y': '862.5673'},
#  'Oregonian': {'x': '-1457.3989', 'y': '229.86986'},
#  'Scarborough': {'x': '-853.18695', 'y': '-93.199974'},
#  'botany': {'x': '-542.42303', 'y': '133.69647'},
#  'canadients': {'x': '430.6702', 'y': '180.60637'},
#  'Minetest': {'x': '-830.7585', 'y': '-575.558'},
#  'Scarred': {'x': '126.61099', 'y': '-471.5797'},
#  'MaleUnderwear': {'x': '-592.9487', 'y': '-602.8155'},
#  'gymnasts': {'x': '41.11145', 'y': '-557.5755'},
#  'Songwriters': {'x': '-979.1038', 'y': '-805.19104'},
#  'theology': {'x': '-280.6434', 'y': '641.9645'},
#  'roguelikes': {'x': '-687.33105', 'y': '-359.7456'},
#  'Drugs': {'x': '686.79755', 'y': '538.3635'},
#  'DeepSpaceNine': {'x': '-979.64777', 'y': '711.8906'},
#  'Somerville': {'x': '-434.6361', 'y': '605.2731'},
#  'education': {'x': '-282.40036', 'y': '326.36615'},
#  'Art': {'x': '-452.22095', 'y': '2.4458432'},
#  'TorontoTransit': {'x': '-581.6996', 'y': '17.807674'},
#  'geohashing': {'x': '-428.3524', 'y': '-61.22113'},
#  'todayilearned': {'x': '-548.40717', 'y': '-14.94186'},
#  'evedreddit': {'x': '-492.5608', 'y': '-446.33853'},
#  'sunsetshimmer': {'x': '595.4615', 'y': '1374.2059'},
#  'Minuette': {'x': '381.2805', 'y': '1371.2065'},
#  'asianbabes': {'x': '-1408.8795', 'y': '348.3896'},
#  'DentonGoneWild': {'x': '678.8018', 'y': '138.53485'},
#  'Wake': {'x': '620.5741', 'y': '68.512535'},
#  'broslikeus': {'x': '-795.257', 'y': '-750.36005'},
#  'freeideas': {'x': '156.71193', 'y': '-209.22267'},
#  'yiffcomics': {'x': '-286.82513', 'y': '-7.338107'},
#  'CalPolitics': {'x': '-47.97102', 'y': '652.4933'},
#  'MedievalMusic': {'x': '-600.35004', 'y': '154.81177'},
#  'PalinProblem': {'x': '-407.61514', 'y': '634.4302'},
#  'Mustang': {'x': '-436.10068', 'y': '-135.31946'},
#  'mylittleartsandcrafts': {'x': '622.3393', 'y': '1501.0719'},
#  'Chilledout': {'x': '-1002.8889', 'y': '-1890.7915'},
#  'photoshopbattles': {'x': '80.41276', 'y': '-265.94455'},
#  'HBD': {'x': '93.03943', 'y': '522.2932'},
#  'MadTeaParty': {'x': '389.15448', 'y': '-44.484425'},
#  'britishcolumbia': {'x': '340.14706', 'y': '-205.01608'},
#  'weeaboo': {'x': '-761.8846', 'y': '8.346856'},
#  'snacks': {'x': '995.1342', 'y': '394.3059'},
#  'civlib': {'x': '-36.507786', 'y': '95.1506'},
#  'bristolcycling': {'x': '-1673.7855', 'y': '626.3801'},
#  'Blowjobs': {'x': '-303.45578', 'y': '-1040.0629'},
#  'openra': {'x': '-309.32333', 'y': '-489.91'},
#  'law': {'x': '-709.4441', 'y': '1068.572'},
#  'SceneGirls': {'x': '659.0458', 'y': '-796.9283'},
#  'morningpaper': {'x': '-842.0461', 'y': '-294.0231'},
#  'AmericanPolitics': {'x': '-416.09564', 'y': '730.7395'},
#  'talesfromdesigners': {'x': '-1287.46', 'y': '2132.476'},
#  'Autobahn': {'x': '-1111.5938', 'y': '64.446175'},
#  'overpopulation': {'x': '-387.83716', 'y': '212.54361'},
#  'invisiblefist': {'x': '-251.2703', 'y': '278.80423'},
#  'Games': {'x': '-205.1169', 'y': '-98.60761'},
#  'traperkeeper': {'x': '354.56085', 'y': '247.3441'},
#  'bestofindia': {'x': '-381.20978', 'y': '-483.3354'},
#  'photos': {'x': '-27.05671', 'y': '-59.953915'},
#  'androidapps': {'x': '357.83246', 'y': '-905.2986'},
#  'bestof': {'x': '-170.06721', 'y': '344.59702'},
#  'space': {'x': '-505.0715', 'y': '247.06898'},
#  'ChilledChaos': {'x': '-1870.7623', 'y': '-343.9203'},
#  'AtheismF7U12': {'x': '-184.59193', 'y': '988.80206'},
#  'GreenBayPackers': {'x': '811.0261', 'y': '-17.53641'},
#  'psytrance': {'x': '-694.8644', 'y': '242.54732'},
#  'BajaCalifornia': {'x': '309.62277', 'y': '784.75415'},
#  'eulaw': {'x': '-1613.6428', 'y': '613.9184'},
#  'DoesAnybodyElse': {'x': '116.23986', 'y': '501.70248'},
#  'BarryKramer': {'x': '-1860.0743', 'y': '-290.34415'},
#  'Boobies': {'x': '-96.28214', 'y': '-298.9564'},
#  'thibit': {'x': '55.7053', 'y': '754.9939'},
#  'Redlands': {'x': '508.36612', 'y': '678.15894'},
#  'Blondes': {'x': '208.13376', 'y': '-726.16644'},
#  'SanJoseSharks': {'x': '755.84503', 'y': '628.42816'},
#  'health2': {'x': '494.2256', 'y': '300.88586'},
#  'Mylittlemusician': {'x': '515.77954', 'y': '1459.7092'},
#  'astro': {'x': '-499.84143', 'y': '156.94957'},
#  'AdultMovies': {'x': '-481.51697', 'y': '-640.7847'},
#  'chambermusic': {'x': '-921.20715', 'y': '180.41441'},
#  'lucypinder': {'x': '-15.636869', 'y': '94.17492'},
#  'insertions': {'x': '-212.19722', 'y': '-38.780426'},
#  'Cartalk': {'x': '61.048035', 'y': '139.99544'},
#  'MLPvectors': {'x': '558.8347', 'y': '1463.0519'},
#  'pregnant': {'x': '-211.43217', 'y': '-678.1163'},
#  'Columbus': {'x': '-23.57603', 'y': '567.37244'},
#  'allthingsutah': {'x': '-433.21527', 'y': '-1266.8473'},
#  'types': {'x': '440.70007', 'y': '-375.95444'},
#  'strings': {'x': '-310.7695', 'y': '295.79926'},
#  'RepublicOfBooks': {'x': '-469.62503', 'y': '1246.1113'},
#  'illegaltorrents': {'x': '-1561.4675', 'y': '-755.9476'},
#  'Clarksville': {'x': '1124.485', 'y': '1636.6278'},
#  'nanotechnology': {'x': '-94.66694', 'y': '21.487686'},
#  'Applejack': {'x': '333.83362', 'y': '1505.4938'},
#  'entwives': {'x': '308.45972', 'y': '-24.790615'},
#  'fnv': {'x': '-781.535', 'y': '-470.36697'},
#  'AustinBeer': {'x': '774.27924', 'y': '154.089'},
#  'TwoAndTwoIsFive': {'x': '-346.99817', 'y': '472.7486'},
#  'entgamers': {'x': '-164.16463', 'y': '-234.43777'},
#  'liberalarts': {'x': '-41.00178', 'y': '424.2236'},
#  'lua': {'x': '472.6484', 'y': '-316.68375'},
#  'FutureOfReligion': {'x': '-200.80592', 'y': '667.1433'},
#  'beach': {'x': '121.00916', 'y': '-597.76697'},
#  'Eurosceptics': {'x': '-1080.7878', 'y': '701.2486'},
#  'Lyme': {'x': '169.0249', 'y': '-40.45054'},
#  'MyLittleFriends': {'x': '496.03134', 'y': '1501.2893'},
#  'Nilesy': {'x': '-1772.0912', 'y': '-378.07568'},
#  'worldnews2': {'x': '-269.26166', 'y': '255.10426'},
#  'tamrielscholarsguild': {'x': '-1019.229', 'y': '170.00583'},
#  'PhilosophyofScience': {'x': '-366.9485', 'y': '321.79376'},
#  'blogs': {'x': '-1285.528', 'y': '-278.68164'},
#  'harrypotter': {'x': '194.10732', 'y': '-200.10448'},
#  'tapirs': {'x': '427.8146', 'y': '-517.0276'},
#  'CelebFakes': {'x': '-65.28207', 'y': '-803.15594'},
#  'bdsm': {'x': '-148.12437', 'y': '-973.9125'},
#  'linux_gaming': {'x': '-217.41005', 'y': '-415.47577'},
#  'neuroscience': {'x': '-370.07996', 'y': '263.31693'},
#  'Catholicism': {'x': '58.49654', 'y': '882.20044'},
#  'cosmology': {'x': '-177.25018', 'y': '302.9039'},
#  'redditmemes': {'x': '-237.1619', 'y': '211.38742'},
#  'SouthCarolinaPolitics': {'x': '-233.50948', 'y': '555.0903'},
#  'NotForTesting': {'x': '66.55869', 'y': '-558.60144'},
#  'AdultCorner': {'x': '-383.5168', 'y': '-1129.8511'},
#  'askscience': {'x': '-221.95285', 'y': '244.94807'},
#  'DallasMeetups': {'x': '86.99006', 'y': '-563.2615'},
#  'EatingDisorders': {'x': '1142.1608', 'y': '-389.40814'},
#  'Haunted': {'x': '-1684.8132', 'y': '22.16625'},
#  'nakedladies': {'x': '-43.094097', 'y': '-545.2522'},
#  'photocritique': {'x': '40.473896', 'y': '-215.63431'},
#  'DinosaursandReligion': {'x': '-324.33194', 'y': '722.7536'},
#  'RepublicOfModeration': {'x': '-403.7148', 'y': '1249.7064'},
#  'postcolonialism': {'x': '62.134544', 'y': '-121.25588'},
#  'newyork': {'x': '123.401665', 'y': '887.24335'},
#  'deutschland': {'x': '-1095.4321', 'y': '128.77704'},
#  'tacos': {'x': '1035.8287', 'y': '165.9383'},
#  'gayfacials': {'x': '-163.81776', 'y': '-101.83613'},
#  'gonewildstories': {'x': '103.207565', 'y': '-128.1088'},
#  'AskComputerScience': {'x': '143.89058', 'y': '171.0954'},
#  'fuckhead': {'x': '143.64682', 'y': '-564.53357'},
#  'TransGoneWild': {'x': '243.05446', 'y': '184.56189'},
#  'nsfw2': {'x': '-212.73006', 'y': '-118.51871'},
#  'addiction': {'x': '544.4015', 'y': '-39.107956'},
#  'portlandoregon': {'x': '-1317.1018', 'y': '357.21246'},
#  'darkstep': {'x': '-953.37366', 'y': '250.55043'},
#  'JanaDefi': {'x': '625.57574', 'y': '-277.01572'},
#  'effzeh': {'x': '792.6858', 'y': '-44.15162'},
#  'tolerantatheism': {'x': '-20.165428', 'y': '734.47845'},
#  'CatsBeingDicks': {'x': '954.2443', 'y': '-722.7635'},
#  'SelenaGomez': {'x': '-18.405056', 'y': '-521.376'},
#  'SyntheticBiology': {'x': '-502.12836', 'y': '289.85638'},
#  'photoshawwp': {'x': '-714.7802', 'y': '-139.92389'},
#  'startups': {'x': '-971.96783', 'y': '353.37018'},
#  'TheoryOfPony': {'x': '352.7228', 'y': '1340.0004'},
#  'intentionalcommunity': {'x': '-117.02708', 'y': '-44.0614'},
#  'ImaginaryCarnage': {'x': '-151.30333', 'y': '-142.01099'},
#  'scootaloo': {'x': '246.13716', 'y': '1369.2771'},
#  'AskGames': {'x': '-195.76407', 'y': '-49.305016'},
#  'wave': {'x': '-207.40088', 'y': '-268.22015'},
#  'mylittlelinux': {'x': '474.8911', 'y': '1310.6295'},
#  'catsorgtfo': {'x': '949.26013', 'y': '-687.53876'},
#  'BrowseMyReddit': {'x': '158.3598', 'y': '631.76154'},
#  'offbeat': {'x': '-542.1907', 'y': '199.67288'},
#  'fights': {'x': '803.6572', 'y': '-707.4128'},
#  'SRDBrokeMovies': {'x': '-314.96634', 'y': '390.82968'},
#  'TheNightmareFactory': {'x': '-1357.888', 'y': '-85.298386'},
#  'TripSit': {'x': '397.58508', 'y': '105.16918'},
#  'gnu': {'x': '479.47717', 'y': '-746.98627'},
#  'funny': {'x': '-81.630264', 'y': '-51.344467'},
#  'photoplunder': {'x': '-569.28937', 'y': '-283.79745'},
#  'rpg_gamers': {'x': '-956.10236', 'y': '-177.13005'},
#  'giveadvice': {'x': '217.75688', 'y': '189.37872'},
#  'gayyoungold': {'x': '83.35635', 'y': '204.92407'},
#  'culturalexchange': {'x': '-250.53192', 'y': '147.50502'},
#  'addictinggames': {'x': '-526.3981', 'y': '-626.0646'},
#  'ClimateCrisis': {'x': '-351.7207', 'y': '434.09085'},
#  'autism': {'x': '111.822815', 'y': '67.27003'},
#  'androidgames': {'x': '404.75143', 'y': '-892.5308'},
#  'PandR': {'x': '-1038.2689', 'y': '446.55695'},
#  'bleach': {'x': '-517.99506', 'y': '-492.15775'},
#  'TFTools': {'x': '-1050.5913', 'y': '-98.69595'},
#  'Gaytheists': {'x': '-222.57318', 'y': '780.7278'},
#  'undiagnosed': {'x': '-815.6991', 'y': '658.9007'},
#  'hip_hop': {'x': '-811.14264', 'y': '187.19797'},
#  'antiatheism': {'x': '-138.48524', 'y': '704.8534'},
#  'futurama': {'x': '-556.66943', 'y': '293.34827'},
#  'LosingMyReligion': {'x': '-318.77197', 'y': '817.3971'},
#  'PrankThem': {'x': '1232.0209', 'y': '1689.3453'},
#  'makecomics': {'x': '-739.30865', 'y': '679.77606'},
#  'shotacub': {'x': '-242.68077', 'y': '24.133781'},
#  'freelancer': {'x': '-562.8941', 'y': '-231.96751'},
#  'nsfwvideos': {'x': '-723.776', 'y': '319.00018'},
#  'warehouse13': {'x': '-586.6704', 'y': '580.19617'},
#  'exAdventist': {'x': '-186.56175', 'y': '695.28735'},
#  'DarkAngels': {'x': '-962.1898', 'y': '-252.23553'},
#  'netjerk': {'x': '1445.973', 'y': '272.09366'},
#  'thesims': {'x': '2256.501', 'y': '1017.5038'},
#  'treeharmony': {'x': '894.4026', 'y': '1601.7032'},
#  'Baking': {'x': '919.8883', 'y': '333.41092'},
#  'CIRCLEJERKERS': {'x': '-241.47627', 'y': '59.571945'},
#  'writing': {'x': '-537.21436', 'y': '95.503174'},
#  'SFBC': {'x': '804.55536', 'y': '671.69086'},
#  'GirlsFinishingTheJob': {'x': '-474.24802', 'y': '-184.33194'},
#  'cedarrapids': {'x': '701.1732', 'y': '1315.5189'},
#  'randomactsofbirthday': {'x': '-1247.2087', 'y': '717.17474'},
#  'alphas': {'x': '-837.37604', 'y': '779.83405'},
#  'DebateReligion': {'x': '-295.40308', 'y': '740.1886'},
#  'datgap': {'x': '-305.49216', 'y': '-63.683872'},
#  'EuroGirls': {'x': '-69.917145', 'y': '-907.0348'},
#  'CelebrityPenis': {'x': '-725.9825', 'y': '-778.63464'},
#  'AnimatedGifs': {'x': '-2230.959', 'y': '-15.39229'},
#  'loseit': {'x': '503.03683', 'y': '282.81998'},
#  'linguistics': {'x': '-353.43494', 'y': '230.98705'},
#  'wowrecruitafriend': {'x': '-81.76247', 'y': '-1314.1473'},
#  'WeAreTheMusicMakers': {'x': '-741.6333', 'y': '292.37936'},
#  'Voyeur': {'x': '-107.97519', 'y': '-106.706696'},
#  'Nebraska': {'x': '170.1007', 'y': '810.40814'},
#  'GiantMonsters': {'x': '-999.84406', 'y': '-16.12147'},
#  'spop': {'x': '-1293.653', 'y': '-2298.932'},
#  'jpics': {'x': '-128.07372', 'y': '286.73987'},
#  'AsiaTalk': {'x': '-923.6833', 'y': '-1054.4535'},
#  'nnnnnnnsfwwwwwwwwwwww': {'x': '262.82455', 'y': '676.95593'},
#  'WritersGroup': {'x': '-707.00793', 'y': '-246.3686'},
#  'LibraryofReddit': {'x': '13.968284', 'y': '355.3939'},
#  'MachinePorn': {'x': '-17.363111', 'y': '36.81601'},
#  'learnjavascript': {'x': '431.86804', 'y': '-261.8354'},
#  'randomactsoftraffic': {'x': '-1314.2433', 'y': '758.97314'},
#  'MensRights': {'x': '10.886723', 'y': '-185.22537'},
#  'facedownassup': {'x': '156.04842', 'y': '-253.75739'},
#  'jailbait': {'x': '258.16983', 'y': '-806.0115'},
#  'unitedkingdom': {'x': '-215.35289', 'y': '-332.58722'},
#  'dyke': {'x': '15.215573', 'y': '29.221758'},
#  'whatissnoodoing': {'x': '726.8829', 'y': '-242.05586'},
#  'r4rDFW': {'x': '362.1283', 'y': '795.13446'},
#  'AnnieWersching': {'x': '122.53506', 'y': '-755.48285'},
#  'spaceflight': {'x': '-763.696', 'y': '-70.38507'},
#  'lol': {'x': '-116.563545', 'y': '265.61884'},
#  'MetaPorn': {'x': '238.89426', 'y': '105.51321'},
#  'USPE08': {'x': '-340.67456', 'y': '538.3899'},
#  'raisingkids': {'x': '-115.972404', 'y': '586.0489'},
#  'DnB': {'x': '-889.85046', 'y': '239.89314'},
#  'Random_Acts_Of_Amazon': {'x': '-746.9658', 'y': '611.6928'},
#  'HotShemales': {'x': '419.12985', 'y': '273.50885'},
#  'Heroes': {'x': '-947.62836', 'y': '677.01807'},
#  'pontoozle': {'x': '-81.00539', 'y': '-421.51257'},
#  'BarefootRunning': {'x': '660.3065', 'y': '172.74632'},
#  'gems': {'x': '1020.1349', 'y': '312.52332'},
#  'TF2fashionadvice': {'x': '-1291.222', 'y': '-651.14795'},
#  'gonewild_HD': {'x': '-526.7132', 'y': '-749.0952'},
#  'happentobegay': {'x': '-21.309807', 'y': '162.20149'},
#  'SFGiants': {'x': '788.8644', 'y': '625.72986'},
#  'RomeSweetRome': {'x': '-138.9538', 'y': '145.83392'},
#  'milf': {'x': '-114.10128', 'y': '-722.9222'},
#  'PrettyOlderWomen': {'x': '-102.62441', 'y': '-1031.4082'},
#  'cults': {'x': '-143.68008', 'y': '653.34125'},
#  'christianmemes': {'x': '-578.0038', 'y': '982.5089'},
#  'ImaginaryBoners': {'x': '-325.0549', 'y': '-63.42448'},
#  'katawashoujo': {'x': '-560.37915', 'y': '-312.92963'},
#  'panties': {'x': '283.01614', 'y': '-422.90833'},
#  'eDrawtica': {'x': '-354.5806', 'y': '-904.1032'},
#  'gamingnews': {'x': '-103.48345', 'y': '166.80472'},
#  'UKJobs': {'x': '685.3962', 'y': '-248.01492'},
#  'r4nonmonogamy': {'x': '496.3596', 'y': '1188.0637'},
#  'BurnNotice': {'x': '-1200.247', 'y': '851.78253'},
#  'Pumping': {'x': '-44.04451', 'y': '-397.87732'},
#  'blog': {'x': '52.466652', 'y': '548.0639'},
#  'fibula': {'x': '166.03148', 'y': '-542.26996'},
#  'GirlsinLaceFishnets': {'x': '2023.3806', 'y': '947.03754'},
#  'newreddits_nsfw': {'x': '-317.42914', 'y': '106.06863'},
#  'ChineseMedicine': {'x': '202.15913', 'y': '1249.5869'},
#  'FreeRepublic': {'x': '-433.33655', 'y': '1386.7025'},
#  'newindianreddits': {'x': '-640.893', 'y': '-141.83951'},
#  'workgonewild': {'x': '-246.58543', 'y': '-65.637985'},
#  'DivaToolbox': {'x': '203.02345', 'y': '-152.53384'},
#  'mjpanzer': {'x': '84.18057', 'y': '-577.80133'},
#  'sciencefaqs': {'x': '-317.27875', 'y': '227.5999'},
#  'women': {'x': '107.08727', 'y': '-182.67107'},
#  'RepublicOfPolitics': {'x': '-436.34326', 'y': '1240.4135'},
#  'APT': {'x': '-1125.069', 'y': '-373.26367'},
#  'metanarchism': {'x': '-381.96802', 'y': '520.2083'},
#  'Naruto_Hentai': {'x': '-453.72098', 'y': '53.016235'},
#  'Frihet': {'x': '-964.9878', 'y': '-72.28975'},
#  'creepymusic': {'x': '-1040.9292', 'y': '86.448166'},
#  'ContinuousStories': {'x': '-894.28186', 'y': '-581.33575'},
#  'RoboWars': {'x': '-1151.1467', 'y': '671.00934'},
#  'community': {'x': '-974.4854', 'y': '508.63306'},
#  'disability': {'x': '947.9911', 'y': '-47.01606'},
#  'mynameisjonas': {'x': '83.47602', 'y': '-555.2055'},
#  'presshearttocontinue': {'x': '-1659.7948', 'y': '-305.50763'},
#  'day9': {'x': '-478.36417', 'y': '-1087.5798'},
#  'TheFapZone': {'x': '-86.87607', 'y': '124.88136'},
#  'PhilosophyofReligion': {'x': '-347.9439', 'y': '794.68414'},
#  'verizon': {'x': '429.79117', 'y': '-485.84818'},
#  'BotanicalPorn': {'x': '28.78363', 'y': '-9.776114'},
#  'bjj': {'x': '706.2053', 'y': '-220.73283'},
#  'trianglejerk': {'x': '-749.029', 'y': '-946.1592'},
#  'IdiotsFightingThings': {'x': '702.119', 'y': '-716.5932'},
#  'onlinejournalism': {'x': '-95.22353', 'y': '-77.22978'},
#  'ukulele': {'x': '-729.336', 'y': '236.01039'},
#  'badscience': {'x': '-357.6544', 'y': '180.15651'},
#  'RedditForensicTools': {'x': '-4.0743933', 'y': '379.52075'},
#  'ShittySeduction': {'x': '957.33636', 'y': '-349.8626'},
#  'Animals': {'x': '323.01566', 'y': '-189.6503'},
#  'htgawm': {'x': '-818.7868', 'y': '498.27826'},
#  'eroticaudio': {'x': '-429.9015', 'y': '-801.49396'},
#  'SRSMen': {'x': '177.57204', 'y': '154.90398'},
#  'LOLscrims': {'x': '-665.973', 'y': '-829.7612'},
#  'sedditchallenge': {'x': '796.2093', 'y': '433.18875'},
#  'RandomActsOfBlowJob': {'x': '325.55264', 'y': '926.4651'},
#  'socialism': {'x': '-491.56247', 'y': '830.19525'},
#  'FileHostingServices': {'x': '-525.6115', 'y': '1046.4359'},
#  'reddittraveljetblue': {'x': '-174.34628', 'y': '207.82584'},
#  'bisexuality': {'x': '234.36731', 'y': '460.7414'},
#  'Gore': {'x': '-162.71817', 'y': '-672.4603'},
#  'fresno': {'x': '621.16113', 'y': '578.46906'},
#  'Erotic_photos': {'x': '-194.16489', 'y': '-325.54904'},
#  'biology': {'x': '-416.2769', 'y': '299.99487'},
#  'openaccesspapers': {'x': '-313.08862', 'y': '244.62096'},
#  'AmericanHorrorStory': {'x': '-904.95404', 'y': '469.2938'},
#  'vipassana': {'x': '4.3697314', 'y': '1471.5093'},
#  'LearnJapanese': {'x': '-820.29974', 'y': '-634.102'},
#  'normalboots': {'x': '-1698.2319', 'y': '-428.28754'},
#  'assscience': {'x': '-389.98914', 'y': '105.364845'},
#  ...}
